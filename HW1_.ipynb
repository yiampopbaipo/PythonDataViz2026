# %% [markdown]
# <a href="https://colab.research.google.com/github/yiampopbaipo/PythonDataViz2026/blob/main/HW1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("673020272-8");
# Out:
# 673020272-8
